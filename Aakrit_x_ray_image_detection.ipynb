# %% [markdown]
# #Pneumonia/ COVID-19/ SARS Detection using Computer Vision

# %% [markdown]
# ### This notebook aims to use Neural Networks to build an image classifier using images of X-Ray scans and classifying them into the detected diseases.
#
# The dataset has train, test, and validation images, split in Pneumonia scans and normal x-ray scans.
#
# For my solution, I created a Convolutional Neural Network, and used Tensorflow and Keras as my deep learning Frameworks.

# %%
from google.colab import files
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import random as rn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline

# %%
path = '/content/drive/My Drive/chest_xray'


# define paths
train_normal_dir = path + '/train/NORMAL/'
train_pneu_dir = path + '/train/PNEUMONIA/'

test_normal_dir = path + '/test/NORMAL/'
test_pneu_dir = path + '/test/PNEUMONIA/'

val_normal_dir = path + '/val/NORMAL/'
val_pneu_dir = path + '/val/PNEUMONIA/'


# find all files, all files have extension jpeg
train_normal_cases = glob.glob(train_normal_dir + '*jpeg')
train_pneu_cases = glob.glob(train_pneu_dir + '*jpeg')

test_normal_cases = glob.glob(test_normal_dir + '*jpeg')
test_pneu_cases = glob.glob(test_pneu_dir + '*jpeg')

val_normal_cases = glob.glob(val_normal_dir + '*jpeg')
val_pneu_cases = glob.glob(val_pneu_dir + '*jpeg')

# create lists for train, test & validation cases, create labels as well
train_list = []
test_list = []
val_list = []

for x in train_normal_cases:
    train_list.append([x, 0])
    
for x in train_pneu_cases:
    train_list.append([x, 1])
    
for x in test_normal_cases:
    test_list.append([x, 0])
    
for x in test_pneu_cases:
    test_list.append([x, 1])
    
for x in val_normal_cases:
    val_list.append([x, 0])
    
for x in val_pneu_cases:
    val_list.append([x, 1])


# shuffle/randomize data as they were loaded in order: normal cases, then pneumonia cases
rn.shuffle(train_list)
rn.shuffle(test_list)
rn.shuffle(val_list)


# create dataframes
train_df = pd.DataFrame(train_list, columns=['image', 'label'])
test_df = pd.DataFrame(test_list, columns=['image', 'label'])
val_df = pd.DataFrame(val_list, columns=['image', 'label'])

# %%
#plotting pneumonia vs. normal scans in the train, test, and val datasets
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.countplot(train_df['label'])
plt.title('Train data')

plt.subplot(1,3,2)
sns.countplot(test_df['label'])
plt.title('Test data')

plt.subplot(1,3,3)
sns.countplot(val_df['label'])
plt.title('Validation data')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#loading some images 
plt.figure(figsize=(20,8))
for i,img_path in enumerate(train_df[train_df['label'] == 1][0:4]['image']):
    plt.subplot(2,4,i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Pneumonia')
    
for i,img_path in enumerate(train_df[train_df['label'] == 0][0:4]['image']):
    plt.subplot(2,4,4+i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Normal')

# %%
def process_data(img_path):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (196, 196))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = img/255.0
    img = np.reshape(img, (196,196,1))
    
    return img

def compose_dataset(df):
    data = []
    labels = []

    for img_path, label in df.values:
        data.append(process_data(img_path))
        labels.append(label)
        
    return np.array(data), np.array(labels)

# %%
X_train, y_train = compose_dataset(train_df)
X_test, y_test = compose_dataset(test_df)
X_val, y_val = compose_dataset(val_df)

print('Train data shape: {}, Labels shape: {}'.format(X_train.shape, y_train.shape))
print('Test data shape: {}, Labels shape: {}'.format(X_test.shape, y_test.shape))
print('Validation data shape: {}, Labels shape: {}'.format(X_val.shape, y_val.shape))
# Out:
# Train data shape: (5233, 196, 196, 1), Labels shape: (5233,)
# Test data shape: (624, 196, 196, 1), Labels shape: (624,)
# Validation data shape: (16, 196, 196, 1), Labels shape: (16,)

# %%
# define generator - data augmentation to make model less prone to overfitting
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range = 0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

# fit generator on our train features
datagen.fit(X_train)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_val = to_categorical(y_val)

# %%
#build the model
model = Sequential()

model.add(Conv2D(filters=8, kernel_size=(7,7), padding='same', activation='relu', input_shape=(196, 196, 1)))
model.add(Conv2D(filters=8, kernel_size=(7,7), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
model.add(Conv2D(filters=16, kernel_size=(5,5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#flattening
model.add(Flatten())
#full connection
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))
#compiling the cnn
optimizer = Adam(lr=0.0001, decay=1e-5)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

callback = EarlyStopping(monitor='loss', patience=6)
history = model.fit(datagen.flow(X_train,y_train, batch_size=4), validation_data=(X_test, y_test), epochs = 100, verbose = 1, callbacks=[callback], class_weight={0:6.0, 1:0.5})
# Out:
# Epoch 1/100
# 1309/1309 [==============================] - 21s 16ms/step - loss: 0.6795 - accuracy: 0.4856 - val_loss: 0.4069 - val_accuracy: 0.8029
# Epoch 2/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.3452 - accuracy: 0.8236 - val_loss: 0.2922 - val_accuracy: 0.8798
# Epoch 3/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.2875 - accuracy: 0.8550 - val_loss: 0.4935 - val_accuracy: 0.7965
# Epoch 4/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.2482 - accuracy: 0.8764 - val_loss: 0.7817 - val_accuracy: 0.7067
# Epoch 5/100
# 1309/1309 [==============================] - 21s 16ms/step - loss: 0.2501 - accuracy: 0.8771 - val_loss: 0.2839 - val_accuracy: 0.8782
# Epoch 6/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.2164 - accuracy: 0.8964 - val_loss: 0.3039 - val_accuracy: 0.8702
# Epoch 7/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1998 - accuracy: 0.9022 - val_loss: 0.2871 - val_accuracy: 0.8750
# Epoch 8/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.2089 - accuracy: 0.8985 - val_loss: 0.2732 - val_accuracy: 0.8942
# Epoch 9/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1864 - accuracy: 0.9050 - val_loss: 0.2588 - val_accuracy: 0.9022
# Epoch 10/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1929 - accuracy: 0.9031 - val_loss: 0.3825 - val_accuracy: 0.8734
# Epoch 11/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1883 - accuracy: 0.9148 - val_loss: 0.2526 - val_accuracy: 0.8974
# Epoch 12/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1773 - accuracy: 0.9222 - val_loss: 0.3111 - val_accuracy: 0.8942
# Epoch 13/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1809 - accuracy: 0.9155 - val_loss: 0.2406 - val_accuracy: 0.9167
# Epoch 14/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1612 - accuracy: 0.9236 - val_loss: 0.2853 - val_accuracy: 0.9054
# Epoch 15/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1691 - accuracy: 0.9182 - val_loss: 0.2704 - val_accuracy: 0.9087
# Epoch 16/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1614 - accuracy: 0.9260 - val_loss: 0.2548 - val_accuracy: 0.8958
# Epoch 17/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1556 - accuracy: 0.9238 - val_loss: 0.2784 - val_accuracy: 0.9183
# Epoch 18/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1443 - accuracy: 0.9339 - val_loss: 0.2383 - val_accuracy: 0.9071
# Epoch 19/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1503 - accuracy: 0.9301 - val_loss: 0.2570 - val_accuracy: 0.9135
# Epoch 20/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1312 - accuracy: 0.9366 - val_loss: 0.2879 - val_accuracy: 0.8798
# Epoch 21/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1502 - accuracy: 0.9304 - val_loss: 0.2453 - val_accuracy: 0.9022
# Epoch 22/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1456 - accuracy: 0.9280 - val_loss: 0.2519 - val_accuracy: 0.9087
# Epoch 23/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1249 - accuracy: 0.9398 - val_loss: 0.2592 - val_accuracy: 0.9183
# Epoch 24/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1403 - accuracy: 0.9322 - val_loss: 0.2328 - val_accuracy: 0.9215
# Epoch 25/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1351 - accuracy: 0.9345 - val_loss: 0.2284 - val_accuracy: 0.9119
# Epoch 26/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1236 - accuracy: 0.9431 - val_loss: 0.2546 - val_accuracy: 0.9135
# Epoch 27/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1260 - accuracy: 0.9379 - val_loss: 0.2956 - val_accuracy: 0.9087
# Epoch 28/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1156 - accuracy: 0.9408 - val_loss: 0.3791 - val_accuracy: 0.8910
# Epoch 29/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1103 - accuracy: 0.9431 - val_loss: 0.2737 - val_accuracy: 0.8958
# Epoch 30/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1299 - accuracy: 0.9381 - val_loss: 0.5048 - val_accuracy: 0.9006
# Epoch 31/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1281 - accuracy: 0.9367 - val_loss: 0.2742 - val_accuracy: 0.9151
# Epoch 32/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1105 - accuracy: 0.9455 - val_loss: 0.3605 - val_accuracy: 0.9022
# Epoch 33/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1269 - accuracy: 0.9410 - val_loss: 0.2546 - val_accuracy: 0.9038
# Epoch 34/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1023 - accuracy: 0.9503 - val_loss: 0.3533 - val_accuracy: 0.8878
# Epoch 35/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1205 - accuracy: 0.9440 - val_loss: 0.3042 - val_accuracy: 0.9103
# Epoch 36/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.0994 - accuracy: 0.9522 - val_loss: 0.2794 - val_accuracy: 0.9038
# Epoch 37/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1072 - accuracy: 0.9450 - val_loss: 0.2589 - val_accuracy: 0.9151
# Epoch 38/100
# 1309/1309 [==============================] - 20s 15ms/step - loss: 0.1140 - accuracy: 0.9448 - val_loss: 0.4254 - val_accuracy: 0.8878
# Epoch 39/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1065 - accuracy: 0.9509 - val_loss: 0.2571 - val_accuracy: 0.9135
# Epoch 40/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1016 - accuracy: 0.9517 - val_loss: 0.3158 - val_accuracy: 0.9071
# Epoch 41/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1091 - accuracy: 0.9503 - val_loss: 0.2325 - val_accuracy: 0.9215
# Epoch 42/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.0849 - accuracy: 0.9557 - val_loss: 0.3588 - val_accuracy: 0.8990
# Epoch 43/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1049 - accuracy: 0.9551 - val_loss: 0.2608 - val_accuracy: 0.9151
# Epoch 44/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1090 - accuracy: 0.9436 - val_loss: 0.3707 - val_accuracy: 0.9038
# Epoch 45/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.0996 - accuracy: 0.9522 - val_loss: 0.3245 - val_accuracy: 0.8990
# Epoch 46/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1020 - accuracy: 0.9507 - val_loss: 0.2947 - val_accuracy: 0.9199
# Epoch 47/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.1020 - accuracy: 0.9501 - val_loss: 0.3207 - val_accuracy: 0.9199
# Epoch 48/100
# 1309/1309 [==============================] - 19s 15ms/step - loss: 0.0868 - accuracy: 0.9551 - val_loss: 0.3319 - val_accuracy: 0.9231

# %%
#evaluate the evolution of loss and accuracy over epochs 
plt.figure(figsize=(20,5))
# plot loss & val loss
plt.subplot(1,2,1)
sns.lineplot(x=history.epoch, y=history.history['loss'], color='red', label='Loss')
sns.lineplot(x=history.epoch, y=history.history['val_loss'], color='orange', label='Val Loss')
plt.title('Loss on train vs test')
plt.legend(loc='best')

# plot accuracy and val accuracy
plt.subplot(1,2,2)
sns.lineplot(x=history.epoch, y=history.history['accuracy'], color='blue', label='Accuracy')
sns.lineplot(x=history.epoch, y=history.history['val_accuracy'], color='green', label='Val Accuracy')
plt.title('Accuracy on train vs test')
plt.legend(loc='best')

plt.show()

# %%
y_test_hat = model.predict(X_test, batch_size=4)
y_test_hat = np.argmax(y_test_hat, axis=1)
y_test = np.argmax(y_test, axis=1)

# %%
# calculate confusion matrix & classification report
conf_m = confusion_matrix(y_test, y_test_hat)
clas_r = classification_report(y_test, y_test_hat)

# plot confusion matrix as heatmap
plt.figure(figsize=(5,3))
sns.set(font_scale=1.2)
ax = sns.heatmap(conf_m, annot=True,xticklabels=['N', 'P'], yticklabels=['N', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
plt.yticks(rotation=0)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
ax.xaxis.set_ticks_position('top') 
plt.title('Confusion matrix - test data\n(N - Normal, P - pneumonia)')
plt.show()

# print classification report
print('Classification report on test data')
print(clas_r)
# Out:
# Classification report on test data
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       234
#            1       0.92      0.96      0.94       390
#
#     accuracy                           0.92       624
#    macro avg       0.92      0.91      0.92       624
# weighted avg       0.92      0.92      0.92       624

# %%
#check how our validation set (16 cases) will work with trained model and compare real vs predicted label
y_val_hat = model.predict(X_val, batch_size=4)
y_val_hat = np.argmax(y_val_hat, axis=1)
y_val = np.argmax(y_val, axis=1)

# %%
plt.figure(figsize=(20,15))
for i,x in enumerate(X_val):
    plt.subplot(4,4,i+1)
    plt.imshow(x.reshape(196, 196), cmap='gray')
    plt.axis('off')
    plt.title('Predicted: {}, Real: {}'.format(y_val_hat[i], y_val[i]))

# %% [markdown]
# ##THANK YOU!
